# %% [markdown]
# ##Importing the necessary packages

# %%
import numpy as np
import pandas as pd
import time
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import LeakyReLU, Dense, Bidirectional, Activation, Flatten, Dropout
from keras.layers import Conv2DTranspose, Conv2D, LSTM, BatchNormalization, MaxPooling2D, Reshape
from keras.utils import to_categorical
from keras.regularizers import L1L2
from keras.initializers import lecun_uniform
from keras.optimizers import Adam
from keras.metrics import categorical_accuracy
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/ECE247-Project"
X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")
# Out:
# /content/drive/.shortcut-targets-by-id/1ELPC9CkLUbTPdE0JP9VLaPzrtY2b7Uf_/ECE247-Project

# %%
# setup tensorflow + TPU 
print("Tensorflow version " + tf.__version__)

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
  print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
  raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.TPUStrategy(tpu)
# Out:
# Tensorflow version 2.11.0
# Running on TPU  ['10.76.91.210:8470']

# %% [markdown]
# ##Loading and visualizing the dataset

# %%
## Loading and visualizing the data

## Adjusting the labels so that 

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

## Visualizing the data

ch_data = X_train_valid[:,8,:] # extracts the 9th channel from the data


class_0_ind = np.where(y_train_valid == 0) # finds the indices where the label is 0
ch_data_class_0 = ch_data[class_0_ind] # finds the data where label is 0
avg_ch_data_class_0 = np.mean(ch_data_class_0,axis=0) # finds the average representation of the 9th channel when label is 0


class_1_ind = np.where(y_train_valid == 1)
ch_data_class_1 = ch_data[class_1_ind]
avg_ch_data_class_1 = np.mean(ch_data_class_1,axis=0)

class_2_ind = np.where(y_train_valid == 2)
ch_data_class_2 = ch_data[class_2_ind]
avg_ch_data_class_2 = np.mean(ch_data_class_2,axis=0)

class_3_ind = np.where(y_train_valid == 3)
ch_data_class_3 = ch_data[class_3_ind]
avg_ch_data_class_3 = np.mean(ch_data_class_3,axis=0)


plt.plot(np.arange(1000),avg_ch_data_class_0)
plt.plot(np.arange(1000),avg_ch_data_class_1)
plt.plot(np.arange(1000),avg_ch_data_class_2)
plt.plot(np.arange(1000),avg_ch_data_class_3)
plt.axvline(x=500, label='line at t=500',c='cyan')

plt.legend(["Cue Onset left", "Cue Onset right", "Cue onset foot", "Cue onset tongue"])

# %%
#Numpy and Keras Random Seed Assignment
np.random.seed(1)
k_initializer = lecun_uniform(seed=42)

# %%
def data_prep(X, y, sub_sample, average, noise, max_timeStep=500, debug_mode=False):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,max_timeStep)
    X = X[:,:,0:max_timeStep]
    if debug_mode: print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    if debug_mode: print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    if debug_mode: print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    if debug_mode: print('Shape of X after subsampling and concatenating:',total_X.shape)
    return total_X,total_y


X_train_valid_prep,y_train_valid_prep = data_prep(X_train_valid, y_train_valid, 2, 2, True, 1000, True)
# Out:
# Shape of X after trimming: (2115, 22, 1000)
# Shape of X after maxpooling: (2115, 22, 500)
# Shape of X after averaging+noise and concatenating: (4230, 22, 500)
# Shape of X after subsampling and concatenating: (8460, 22, 500)

# %% [markdown]
# ##Preparing the training, validation, and test datasets

# %%
## Random splitting and reshaping the data
def data_train_valid_test_split(sub_sample=2, average=2, noise=True, sobject_id=None, max_timeStep=500, debug_mode=False):

  # Check if we are generating the model for the whole subject
  if sobject_id:
    X_train_sub = X_train_valid[np.where(person_train_valid == sobject_id)[0]]
    y_train_sub = y_train_valid[np.where(person_train_valid == sobject_id)[0]]
    X_test_sub = X_test[np.where(person_test == sobject_id)[0]]
    y_test_sub = y_test[np.where(person_test == sobject_id)[0]]
  else:
    X_train_sub = np.copy(X_train_valid)
    y_train_sub = np.copy(y_train_valid)
    X_test_sub = np.copy(X_test)
    y_test_sub = np.copy(y_test)

  # First generating the training and validation indices using random splitting
  # Since the ratio of test set to the whole training set is about 17%, we chose
  # the same ratio for spliting the training and validation set
  n_train_valid = X_train_sub.shape[0]
  n_valid = int(np.floor(0.17*n_train_valid))
  ind_valid = np.random.choice(n_train_valid, n_valid, replace=False)
  ind_train = np.array(list(set(range(n_train_valid)).difference(set(ind_valid))))

  # Creating the training and validation sets using the generated indices
  (X_train, X_valid) = X_train_sub[ind_train], X_train_sub[ind_valid] 
  (y_train, y_valid) = y_train_sub[ind_train], y_train_sub[ind_valid]


  ## Preprocessing the dataset
  x_train,y_train = data_prep(X_train, y_train, sub_sample, average, noise, max_timeStep, debug_mode)
  x_valid,y_valid = data_prep(X_valid, y_valid, sub_sample, average, noise, max_timeStep, debug_mode)
  X_test_prep,y_test_prep = data_prep(X_test_sub, y_test_sub, sub_sample, average, noise, max_timeStep, debug_mode)

  if debug_mode:
    print('Shape of testing set:',X_test_prep.shape)
    print('Shape of testing labels:',y_test_prep.shape)

    print('Shape of training set:',x_train.shape)
    print('Shape of validation set:',x_valid.shape)
    print('Shape of training labels:',y_train.shape)
    print('Shape of validation labels:',y_valid.shape)


  # Converting the labels to categorical variables for multiclass classification
  y__train = to_categorical(y_train, 4)
  y__valid = to_categorical(y_valid, 4)
  y__test = to_categorical(y_test_prep, 4)

  if debug_mode:
    print('Shape of training labels after categorical conversion:',y_train.shape)
    print('Shape of validation labels after categorical conversion:',y_valid.shape)
    print('Shape of test labels after categorical conversion:',y_test.shape)

  # Adding width of the segment to be 1
  x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
  x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
  x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
  if debug_mode:
    print('Shape of training set after adding width info:',x_train.shape)
    print('Shape of validation set after adding width info:',x_valid.shape)
    print('Shape of test set after adding width info:',x_test.shape)


  # Reshaping the training and validation dataset
  x__train = np.swapaxes(x_train, 1,3)
  x__train = np.swapaxes(x__train, 1,2)
  x__valid = np.swapaxes(x_valid, 1,3)
  x__valid = np.swapaxes(x__valid, 1,2)
  x__test = np.swapaxes(x_test, 1,3)
  x__test = np.swapaxes(x__test, 1,2)
  
  if debug_mode:
    print('Shape of training set after dimension reshaping:',x__train.shape)
    print('Shape of validation set after dimension reshaping:',x__valid.shape)
    print('Shape of test set after dimension reshaping:',x__test.shape)

  return x__train, y__train, x__valid, y__valid, x__test, y__test

# %%
# Generating Train, Validation, and Test data set
x__train, y__train, x__valid, y__valid, x__test, y__test = data_train_valid_test_split(sub_sample=2, average=2, noise=True, sobject_id=None, max_timeStep=500, debug_mode=True)
# Out:
# Shape of X after trimming: (1756, 22, 500)
# Shape of X after maxpooling: (1756, 22, 250)
# Shape of X after averaging+noise and concatenating: (3512, 22, 250)
# Shape of X after subsampling and concatenating: (7024, 22, 250)
# Shape of X after trimming: (359, 22, 500)
# Shape of X after maxpooling: (359, 22, 250)
# Shape of X after averaging+noise and concatenating: (718, 22, 250)
# Shape of X after subsampling and concatenating: (1436, 22, 250)
# Shape of X after trimming: (443, 22, 500)
# Shape of X after maxpooling: (443, 22, 250)
# Shape of X after averaging+noise and concatenating: (886, 22, 250)
# Shape of X after subsampling and concatenating: (1772, 22, 250)
# Shape of testing set: (1772, 22, 250)
# Shape of testing labels: (1772,)
# Shape of training set: (7024, 22, 250)
# Shape of validation set: (1436, 22, 250)
# Shape of training labels: (7024,)
# Shape of validation labels: (1436,)
# Shape of training labels after categorical conversion: (7024,)
# Shape of validation labels after categorical conversion: (1436,)
# Shape of test labels after categorical conversion: (443,)
# Shape of training set after adding width info: (7024, 22, 250, 1)
# Shape of validation set after adding width info: (1436, 22, 250, 1)
# Shape of test set after adding width info: (1772, 22, 250, 1)
# Shape of training set after dimension reshaping: (7024, 250, 1, 22)
# Shape of validation set after dimension reshaping: (1436, 250, 1, 22)
# Shape of test set after dimension reshaping: (1772, 250, 1, 22)

# %% [markdown]
# #(CNN)

# %% [markdown]
# ##(CNN) Defining the architecture of a basic CNN model

# %%
def CNN(initializer, max_timeStep=500, debug_mode=False, learning_rate=1e-3):
  # Building the CNN model using sequential class
  basic_cnn_model = Sequential()

  # Conv. block 1
  basic_cnn_model.add(Conv2D(filters=25, kernel_size=(10,1), padding='same', activation='elu', input_shape=(int(max_timeStep/2),1,22)))
  basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same')) 
  basic_cnn_model.add(BatchNormalization())
  basic_cnn_model.add(Dropout(0.5))

  # Conv. block 2
  basic_cnn_model.add(Conv2D(filters=50, kernel_size=(10,1), padding='same', activation='elu'))
  basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
  basic_cnn_model.add(BatchNormalization())
  basic_cnn_model.add(Dropout(0.5))

  # Conv. block 3
  basic_cnn_model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu'))
  basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
  basic_cnn_model.add(BatchNormalization())
  basic_cnn_model.add(Dropout(0.5))

  # Conv. block 4
  basic_cnn_model.add(Conv2D(filters=200, kernel_size=(10,1), padding='same', activation='elu'))
  basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
  basic_cnn_model.add(BatchNormalization())
  basic_cnn_model.add(Dropout(0.5))

  # Output layer with Softmax activation
  basic_cnn_model.add(Flatten()) # Flattens the input
  basic_cnn_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation

  # Printing the model summary
  if debug_mode:
    basic_cnn_model.summary()

  cnn_optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

  # Compiling the model
  basic_cnn_model.compile(loss='categorical_crossentropy',
                  optimizer=cnn_optimizer,
                  metrics=['accuracy'])

  return basic_cnn_model

# %% [markdown]
# ##(CNN) Compiling, training and validating the model

# %%
n_epochs=100

# Creating and compiling the model
basic_cnn_model = CNN(k_initializer, debug_mode=True)

# Training and validating the model
basic_cnn_model_results = basic_cnn_model.fit(x__train,
            y__train,
            batch_size=64,
            epochs=n_epochs,
            validation_data=(x__valid, y__valid), verbose=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 250, 1, 25)        5525
#
#  max_pooling2d_4 (MaxPooling  (None, 84, 1, 25)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 84, 1, 25)        100
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 84, 1, 25)         0
#
#  conv2d_5 (Conv2D)           (None, 84, 1, 50)         12550
#
#  max_pooling2d_5 (MaxPooling  (None, 28, 1, 50)        0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 28, 1, 50)        200
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 28, 1, 50)         0
#
#  conv2d_6 (Conv2D)           (None, 28, 1, 100)        50100
#
#  max_pooling2d_6 (MaxPooling  (None, 10, 1, 100)       0
#  2D)
#
#  batch_normalization_6 (Batc  (None, 10, 1, 100)       400
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 10, 1, 100)        0
#
#  conv2d_7 (Conv2D)           (None, 10, 1, 200)        200200
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 1, 200)        0
#  2D)
#
#  batch_normalization_7 (Batc  (None, 4, 1, 200)        800
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 4, 1, 200)         0
#
#  flatten_1 (Flatten)         (None, 800)               0
#
#  dense_1 (Dense)             (None, 4)                 3204
#
# =================================================================
# Total params: 273,079
# Trainable params: 272,329
# Non-trainable params: 750
# _________________________________________________________________
# Epoch 1/100
# 110/110 [==============================] - 7s 34ms/step - loss: 2.0001 - accuracy: 0.3249 - val_loss: 1.3704 - val_accuracy: 0.3712
# Epoch 2/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.5350 - accuracy: 0.3908 - val_loss: 1.2038 - val_accuracy: 0.4784
# Epoch 3/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.3275 - accuracy: 0.4459 - val_loss: 1.1523 - val_accuracy: 0.4798
# Epoch 4/100
# 110/110 [==============================] - 3s 25ms/step - loss: 1.1870 - accuracy: 0.4944 - val_loss: 1.2104 - val_accuracy: 0.4659
# Epoch 5/100
# 110/110 [==============================] - 3s 25ms/step - loss: 1.1178 - accuracy: 0.5279 - val_loss: 1.1347 - val_accuracy: 0.5035
# Epoch 6/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.0632 - accuracy: 0.5557 - val_loss: 1.0228 - val_accuracy: 0.5669
# Epoch 7/100
# 110/110 [==============================] - 3s 24ms/step - loss: 1.0297 - accuracy: 0.5683 - val_loss: 1.0090 - val_accuracy: 0.5877
# Epoch 8/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.9803 - accuracy: 0.5951 - val_loss: 0.9831 - val_accuracy: 0.6024
# Epoch 9/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.9479 - accuracy: 0.6083 - val_loss: 0.9545 - val_accuracy: 0.6170
# Epoch 10/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.9087 - accuracy: 0.6318 - val_loss: 0.9092 - val_accuracy: 0.6323
# Epoch 11/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.8721 - accuracy: 0.6479 - val_loss: 0.9722 - val_accuracy: 0.6219
# Epoch 12/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.8363 - accuracy: 0.6602 - val_loss: 0.8974 - val_accuracy: 0.6462
# Epoch 13/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.8051 - accuracy: 0.6790 - val_loss: 0.8905 - val_accuracy: 0.6623
# Epoch 14/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.7792 - accuracy: 0.6926 - val_loss: 0.8847 - val_accuracy: 0.6636
# Epoch 15/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.7225 - accuracy: 0.7124 - val_loss: 0.8675 - val_accuracy: 0.6560
# Epoch 16/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.7368 - accuracy: 0.7044 - val_loss: 0.8310 - val_accuracy: 0.6699
# Epoch 17/100
# 110/110 [==============================] - 3s 28ms/step - loss: 0.6736 - accuracy: 0.7362 - val_loss: 0.8793 - val_accuracy: 0.6574
# Epoch 18/100
# 110/110 [==============================] - 3s 28ms/step - loss: 0.6584 - accuracy: 0.7439 - val_loss: 0.8249 - val_accuracy: 0.6971
# Epoch 19/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.6391 - accuracy: 0.7486 - val_loss: 0.7702 - val_accuracy: 0.7145
# Epoch 20/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.6287 - accuracy: 0.7585 - val_loss: 0.8451 - val_accuracy: 0.6657
# Epoch 21/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.6038 - accuracy: 0.7618 - val_loss: 0.8155 - val_accuracy: 0.6838
# Epoch 22/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.5758 - accuracy: 0.7768 - val_loss: 0.7865 - val_accuracy: 0.6908
# Epoch 23/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.5528 - accuracy: 0.7830 - val_loss: 0.8092 - val_accuracy: 0.6985
# Epoch 24/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.5419 - accuracy: 0.7887 - val_loss: 0.8006 - val_accuracy: 0.7068
# Epoch 25/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.5332 - accuracy: 0.7906 - val_loss: 0.7937 - val_accuracy: 0.7089
# Epoch 26/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.5106 - accuracy: 0.8030 - val_loss: 0.7933 - val_accuracy: 0.7033
# Epoch 27/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.5097 - accuracy: 0.8052 - val_loss: 0.7870 - val_accuracy: 0.7006
# Epoch 28/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.5018 - accuracy: 0.8042 - val_loss: 0.8355 - val_accuracy: 0.6748
# Epoch 29/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.4634 - accuracy: 0.8220 - val_loss: 0.8608 - val_accuracy: 0.6985
# Epoch 30/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.4734 - accuracy: 0.8195 - val_loss: 0.8556 - val_accuracy: 0.6859
# Epoch 31/100
# 110/110 [==============================] - 3s 30ms/step - loss: 0.4422 - accuracy: 0.8280 - val_loss: 0.8056 - val_accuracy: 0.7026
# Epoch 32/100
# 110/110 [==============================] - 3s 27ms/step - loss: 0.4421 - accuracy: 0.8293 - val_loss: 0.8667 - val_accuracy: 0.6964
# Epoch 33/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.4195 - accuracy: 0.8340 - val_loss: 0.7910 - val_accuracy: 0.7082
# Epoch 34/100
# 110/110 [==============================] - 3s 27ms/step - loss: 0.4202 - accuracy: 0.8408 - val_loss: 0.8191 - val_accuracy: 0.6852
# Epoch 35/100
# 110/110 [==============================] - 3s 27ms/step - loss: 0.3948 - accuracy: 0.8468 - val_loss: 0.8596 - val_accuracy: 0.7006
# Epoch 36/100
# 110/110 [==============================] - 3s 27ms/step - loss: 0.4043 - accuracy: 0.8470 - val_loss: 0.8467 - val_accuracy: 0.7145
# Epoch 37/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.3810 - accuracy: 0.8542 - val_loss: 0.8319 - val_accuracy: 0.7270
# Epoch 38/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.3815 - accuracy: 0.8542 - val_loss: 0.8076 - val_accuracy: 0.7075
# Epoch 39/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.3706 - accuracy: 0.8542 - val_loss: 0.8109 - val_accuracy: 0.7263
# Epoch 40/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.3450 - accuracy: 0.8696 - val_loss: 0.8431 - val_accuracy: 0.7096
# Epoch 41/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.3632 - accuracy: 0.8559 - val_loss: 0.8332 - val_accuracy: 0.7096
# Epoch 42/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.3655 - accuracy: 0.8556 - val_loss: 0.8959 - val_accuracy: 0.7013
# Epoch 43/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.3573 - accuracy: 0.8632 - val_loss: 0.8359 - val_accuracy: 0.7256
# Epoch 44/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.3389 - accuracy: 0.8672 - val_loss: 0.8828 - val_accuracy: 0.7221
# Epoch 45/100
# 110/110 [==============================] - 3s 27ms/step - loss: 0.3344 - accuracy: 0.8737 - val_loss: 0.8321 - val_accuracy: 0.7465
# Epoch 46/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.3449 - accuracy: 0.8685 - val_loss: 0.8396 - val_accuracy: 0.7256
# Epoch 47/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.3299 - accuracy: 0.8790 - val_loss: 0.8028 - val_accuracy: 0.7284
# Epoch 48/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.3268 - accuracy: 0.8823 - val_loss: 0.8135 - val_accuracy: 0.7256
# Epoch 49/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.3205 - accuracy: 0.8818 - val_loss: 0.8419 - val_accuracy: 0.7242
# Epoch 50/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.3164 - accuracy: 0.8794 - val_loss: 0.8847 - val_accuracy: 0.7026
# Epoch 51/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.3092 - accuracy: 0.8848 - val_loss: 0.8135 - val_accuracy: 0.7340
# Epoch 52/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2977 - accuracy: 0.8865 - val_loss: 0.9071 - val_accuracy: 0.7006
# Epoch 53/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2969 - accuracy: 0.8868 - val_loss: 0.8645 - val_accuracy: 0.7291
# Epoch 54/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2952 - accuracy: 0.8911 - val_loss: 0.8408 - val_accuracy: 0.7173
# Epoch 55/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2950 - accuracy: 0.8927 - val_loss: 0.8527 - val_accuracy: 0.7375
# Epoch 56/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.2890 - accuracy: 0.8921 - val_loss: 0.8625 - val_accuracy: 0.7284
# Epoch 57/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2714 - accuracy: 0.8965 - val_loss: 0.8839 - val_accuracy: 0.7145
# Epoch 58/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2888 - accuracy: 0.8904 - val_loss: 0.8336 - val_accuracy: 0.7465
# Epoch 59/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2615 - accuracy: 0.8979 - val_loss: 0.8998 - val_accuracy: 0.7242
# Epoch 60/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2590 - accuracy: 0.9032 - val_loss: 0.8900 - val_accuracy: 0.7298
# Epoch 61/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2850 - accuracy: 0.8972 - val_loss: 0.9077 - val_accuracy: 0.7354
# Epoch 62/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2735 - accuracy: 0.8972 - val_loss: 0.8769 - val_accuracy: 0.7361
# Epoch 63/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2553 - accuracy: 0.9021 - val_loss: 1.0692 - val_accuracy: 0.6852
# Epoch 64/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2738 - accuracy: 0.8983 - val_loss: 0.8366 - val_accuracy: 0.7368
# Epoch 65/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2557 - accuracy: 0.9028 - val_loss: 0.8902 - val_accuracy: 0.7409
# Epoch 66/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2604 - accuracy: 0.9013 - val_loss: 0.8641 - val_accuracy: 0.7361
# Epoch 67/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2520 - accuracy: 0.9052 - val_loss: 0.9101 - val_accuracy: 0.7180
# Epoch 68/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.2459 - accuracy: 0.9086 - val_loss: 1.0193 - val_accuracy: 0.7026
# Epoch 69/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2433 - accuracy: 0.9119 - val_loss: 0.9249 - val_accuracy: 0.7221
# Epoch 70/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2569 - accuracy: 0.9060 - val_loss: 0.9095 - val_accuracy: 0.7221
# Epoch 71/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2486 - accuracy: 0.9090 - val_loss: 0.9050 - val_accuracy: 0.7291
# Epoch 72/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2415 - accuracy: 0.9067 - val_loss: 0.8448 - val_accuracy: 0.7451
# Epoch 73/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2364 - accuracy: 0.9114 - val_loss: 0.8665 - val_accuracy: 0.7263
# Epoch 74/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.2320 - accuracy: 0.9176 - val_loss: 0.9307 - val_accuracy: 0.7249
# Epoch 75/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2243 - accuracy: 0.9194 - val_loss: 0.8743 - val_accuracy: 0.7535
# Epoch 76/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.2290 - accuracy: 0.9123 - val_loss: 0.9050 - val_accuracy: 0.7333
# Epoch 77/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2601 - accuracy: 0.9052 - val_loss: 0.8656 - val_accuracy: 0.7423
# Epoch 78/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.2337 - accuracy: 0.9142 - val_loss: 0.8679 - val_accuracy: 0.7305
# Epoch 79/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2263 - accuracy: 0.9198 - val_loss: 0.9099 - val_accuracy: 0.7291
# Epoch 80/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.2361 - accuracy: 0.9151 - val_loss: 0.9168 - val_accuracy: 0.7389
# Epoch 81/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2222 - accuracy: 0.9161 - val_loss: 0.9734 - val_accuracy: 0.7256
# Epoch 82/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2204 - accuracy: 0.9171 - val_loss: 0.9154 - val_accuracy: 0.7221
# Epoch 83/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2185 - accuracy: 0.9204 - val_loss: 0.9201 - val_accuracy: 0.7430
# Epoch 84/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2265 - accuracy: 0.9159 - val_loss: 0.9135 - val_accuracy: 0.7235
# Epoch 85/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.2165 - accuracy: 0.9203 - val_loss: 0.9195 - val_accuracy: 0.7333
# Epoch 86/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.2096 - accuracy: 0.9226 - val_loss: 0.8662 - val_accuracy: 0.7465
# Epoch 87/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1962 - accuracy: 0.9282 - val_loss: 0.8912 - val_accuracy: 0.7389
# Epoch 88/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2107 - accuracy: 0.9188 - val_loss: 0.9217 - val_accuracy: 0.7298
# Epoch 89/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2261 - accuracy: 0.9144 - val_loss: 0.9570 - val_accuracy: 0.7096
# Epoch 90/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2028 - accuracy: 0.9235 - val_loss: 0.9085 - val_accuracy: 0.7458
# Epoch 91/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2051 - accuracy: 0.9254 - val_loss: 0.8790 - val_accuracy: 0.7305
# Epoch 92/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1981 - accuracy: 0.9211 - val_loss: 0.9458 - val_accuracy: 0.7201
# Epoch 93/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1960 - accuracy: 0.9274 - val_loss: 0.9296 - val_accuracy: 0.7458
# Epoch 94/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.2029 - accuracy: 0.9255 - val_loss: 0.9799 - val_accuracy: 0.7235
# Epoch 95/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.2037 - accuracy: 0.9277 - val_loss: 0.9372 - val_accuracy: 0.7333
# Epoch 96/100
# 110/110 [==============================] - 3s 26ms/step - loss: 0.2174 - accuracy: 0.9210 - val_loss: 0.9533 - val_accuracy: 0.7201
# Epoch 97/100
# 110/110 [==============================] - 3s 24ms/step - loss: 0.1986 - accuracy: 0.9240 - val_loss: 0.9777 - val_accuracy: 0.7180
# Epoch 98/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1945 - accuracy: 0.9290 - val_loss: 0.8827 - val_accuracy: 0.7577
# Epoch 99/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1955 - accuracy: 0.9290 - val_loss: 0.9161 - val_accuracy: 0.7298
# Epoch 100/100
# 110/110 [==============================] - 3s 25ms/step - loss: 0.1966 - accuracy: 0.9274 - val_loss: 0.9142 - val_accuracy: 0.7416

# %% [markdown]
# ##(CNN) Visualizing the accuracy and loss trajectory

# %%
# Plotting accuracy trajectory
plt.plot(basic_cnn_model_results.history['accuracy'])
plt.plot(basic_cnn_model_results.history['val_accuracy'])
plt.title('Basic CNN model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(basic_cnn_model_results.history['loss'],'o')
plt.plot(basic_cnn_model_results.history['val_loss'],'o')
plt.title('Basic CNN model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ##(CNN) Testing the performance of the basic CNN model on the held out test set

# %%
## Testing the basic CNN model

cnn_score = basic_cnn_model.evaluate(x__test, y__test, verbose=0)
print('Test accuracy of the basic CNN model:',cnn_score[1])
# Out:
# Test accuracy of the basic CNN model: 0.7048532962799072
