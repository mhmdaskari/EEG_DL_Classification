# %% [markdown]
# ##Importing the necessary packages

# %%
import numpy as np
import pandas as pd
import time
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import LeakyReLU, Dense, Bidirectional, Activation, Flatten, Dropout
from keras.layers import Conv2DTranspose, Conv2D, LSTM, BatchNormalization, MaxPooling2D, Reshape
from keras.utils import to_categorical
from keras.regularizers import L1L2
from keras.initializers import lecun_uniform
from keras.optimizers import Adam
from keras.metrics import categorical_accuracy
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/ECE247-Project"
X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")
# Out:
# /content/drive/.shortcut-targets-by-id/1ELPC9CkLUbTPdE0JP9VLaPzrtY2b7Uf_/ECE247-Project

# %%
# setup tensorflow + TPU 
print("Tensorflow version " + tf.__version__)

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
  print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
  raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.TPUStrategy(tpu)
# Out:
# Tensorflow version 2.11.0
# Running on TPU  ['10.76.91.210:8470']

# %% [markdown]
# ##Loading and visualizing the dataset

# %%
## Loading and visualizing the data

## Adjusting the labels so that 

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

## Visualizing the data

ch_data = X_train_valid[:,8,:] # extracts the 9th channel from the data


class_0_ind = np.where(y_train_valid == 0) # finds the indices where the label is 0
ch_data_class_0 = ch_data[class_0_ind] # finds the data where label is 0
avg_ch_data_class_0 = np.mean(ch_data_class_0,axis=0) # finds the average representation of the 9th channel when label is 0


class_1_ind = np.where(y_train_valid == 1)
ch_data_class_1 = ch_data[class_1_ind]
avg_ch_data_class_1 = np.mean(ch_data_class_1,axis=0)

class_2_ind = np.where(y_train_valid == 2)
ch_data_class_2 = ch_data[class_2_ind]
avg_ch_data_class_2 = np.mean(ch_data_class_2,axis=0)

class_3_ind = np.where(y_train_valid == 3)
ch_data_class_3 = ch_data[class_3_ind]
avg_ch_data_class_3 = np.mean(ch_data_class_3,axis=0)


plt.plot(np.arange(1000),avg_ch_data_class_0)
plt.plot(np.arange(1000),avg_ch_data_class_1)
plt.plot(np.arange(1000),avg_ch_data_class_2)
plt.plot(np.arange(1000),avg_ch_data_class_3)
plt.axvline(x=500, label='line at t=500',c='cyan')

plt.legend(["Cue Onset left", "Cue Onset right", "Cue onset foot", "Cue onset tongue"])

# %%
#Numpy and Keras Random Seed Assignment
np.random.seed(1)
k_initializer = lecun_uniform(seed=42)

# %%
def data_prep(X, y, sub_sample, average, noise, max_timeStep=500, debug_mode=False):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,max_timeStep)
    X = X[:,:,0:max_timeStep]
    if debug_mode: print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    if debug_mode: print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    if debug_mode: print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    if debug_mode: print('Shape of X after subsampling and concatenating:',total_X.shape)
    return total_X,total_y


X_train_valid_prep,y_train_valid_prep = data_prep(X_train_valid, y_train_valid, 2, 2, True, 1000, True)
# Out:
# Shape of X after trimming: (2115, 22, 1000)
# Shape of X after maxpooling: (2115, 22, 500)
# Shape of X after averaging+noise and concatenating: (4230, 22, 500)
# Shape of X after subsampling and concatenating: (8460, 22, 500)

# %% [markdown]
# ##Preparing the training, validation, and test datasets

# %%
## Random splitting and reshaping the data
def data_train_valid_test_split(sub_sample=2, average=2, noise=True, sobject_id=None, max_timeStep=500, debug_mode=False):

  # Check if we are generating the model for the whole subject
  if sobject_id:
    X_train_sub = X_train_valid[np.where(person_train_valid == sobject_id)[0]]
    y_train_sub = y_train_valid[np.where(person_train_valid == sobject_id)[0]]
    X_test_sub = X_test[np.where(person_test == sobject_id)[0]]
    y_test_sub = y_test[np.where(person_test == sobject_id)[0]]
  else:
    X_train_sub = np.copy(X_train_valid)
    y_train_sub = np.copy(y_train_valid)
    X_test_sub = np.copy(X_test)
    y_test_sub = np.copy(y_test)

  # First generating the training and validation indices using random splitting
  # Since the ratio of test set to the whole training set is about 17%, we chose
  # the same ratio for spliting the training and validation set
  n_train_valid = X_train_sub.shape[0]
  n_valid = int(np.floor(0.17*n_train_valid))
  ind_valid = np.random.choice(n_train_valid, n_valid, replace=False)
  ind_train = np.array(list(set(range(n_train_valid)).difference(set(ind_valid))))

  # Creating the training and validation sets using the generated indices
  (X_train, X_valid) = X_train_sub[ind_train], X_train_sub[ind_valid] 
  (y_train, y_valid) = y_train_sub[ind_train], y_train_sub[ind_valid]


  ## Preprocessing the dataset
  x_train,y_train = data_prep(X_train, y_train, sub_sample, average, noise, max_timeStep, debug_mode)
  x_valid,y_valid = data_prep(X_valid, y_valid, sub_sample, average, noise, max_timeStep, debug_mode)
  X_test_prep,y_test_prep = data_prep(X_test_sub, y_test_sub, sub_sample, average, noise, max_timeStep, debug_mode)

  if debug_mode:
    print('Shape of testing set:',X_test_prep.shape)
    print('Shape of testing labels:',y_test_prep.shape)

    print('Shape of training set:',x_train.shape)
    print('Shape of validation set:',x_valid.shape)
    print('Shape of training labels:',y_train.shape)
    print('Shape of validation labels:',y_valid.shape)


  # Converting the labels to categorical variables for multiclass classification
  y__train = to_categorical(y_train, 4)
  y__valid = to_categorical(y_valid, 4)
  y__test = to_categorical(y_test_prep, 4)

  if debug_mode:
    print('Shape of training labels after categorical conversion:',y_train.shape)
    print('Shape of validation labels after categorical conversion:',y_valid.shape)
    print('Shape of test labels after categorical conversion:',y_test.shape)

  # Adding width of the segment to be 1
  x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
  x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
  x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
  if debug_mode:
    print('Shape of training set after adding width info:',x_train.shape)
    print('Shape of validation set after adding width info:',x_valid.shape)
    print('Shape of test set after adding width info:',x_test.shape)


  # Reshaping the training and validation dataset
  x__train = np.swapaxes(x_train, 1,3)
  x__train = np.swapaxes(x__train, 1,2)
  x__valid = np.swapaxes(x_valid, 1,3)
  x__valid = np.swapaxes(x__valid, 1,2)
  x__test = np.swapaxes(x_test, 1,3)
  x__test = np.swapaxes(x__test, 1,2)
  
  if debug_mode:
    print('Shape of training set after dimension reshaping:',x__train.shape)
    print('Shape of validation set after dimension reshaping:',x__valid.shape)
    print('Shape of test set after dimension reshaping:',x__test.shape)

  return x__train, y__train, x__valid, y__valid, x__test, y__test

# %%
# Generating Train, Validation, and Test data set
x__train, y__train, x__valid, y__valid, x__test, y__test = data_train_valid_test_split(sub_sample=2, average=2, noise=True, sobject_id=None, max_timeStep=500, debug_mode=True)
# Out:
# Shape of X after trimming: (1756, 22, 500)
# Shape of X after maxpooling: (1756, 22, 250)
# Shape of X after averaging+noise and concatenating: (3512, 22, 250)
# Shape of X after subsampling and concatenating: (7024, 22, 250)
# Shape of X after trimming: (359, 22, 500)
# Shape of X after maxpooling: (359, 22, 250)
# Shape of X after averaging+noise and concatenating: (718, 22, 250)
# Shape of X after subsampling and concatenating: (1436, 22, 250)
# Shape of X after trimming: (443, 22, 500)
# Shape of X after maxpooling: (443, 22, 250)
# Shape of X after averaging+noise and concatenating: (886, 22, 250)
# Shape of X after subsampling and concatenating: (1772, 22, 250)
# Shape of testing set: (1772, 22, 250)
# Shape of testing labels: (1772,)
# Shape of training set: (7024, 22, 250)
# Shape of validation set: (1436, 22, 250)
# Shape of training labels: (7024,)
# Shape of validation labels: (1436,)
# Shape of training labels after categorical conversion: (7024,)
# Shape of validation labels after categorical conversion: (1436,)
# Shape of test labels after categorical conversion: (443,)
# Shape of training set after adding width info: (7024, 22, 250, 1)
# Shape of validation set after adding width info: (1436, 22, 250, 1)
# Shape of test set after adding width info: (1772, 22, 250, 1)
# Shape of training set after dimension reshaping: (7024, 250, 1, 22)
# Shape of validation set after dimension reshaping: (1436, 250, 1, 22)
# Shape of test set after dimension reshaping: (1772, 250, 1, 22)

# %% [markdown]
# #(Naive LSTM)

# %% [markdown]
# ##(Naive LSTM) Defining the architecture

# %%
def naive_LSTM(initializer, max_timeStep=500, debug_mode=False, learning_rate=1e-3):
  # Building the CNN model using sequential class
  model_naive_lstm = Sequential()

  model_naive_lstm.add(Flatten())
  model_naive_lstm.add(Dense(int(max_timeStep/2)))
  model_naive_lstm.add(Reshape((int(max_timeStep/2),1)))

  model_naive_lstm.add(Bidirectional(LSTM(32, kernel_initializer=initializer, input_shape=(int(max_timeStep/2),1))))
  model_naive_lstm.add(Reshape((64,1)))
  model_naive_lstm.add(Bidirectional(LSTM(16, kernel_initializer=initializer, input_shape=(64,1))))
  model_naive_lstm.add(Reshape((32,1)))
  model_naive_lstm.add(Bidirectional(LSTM(8, kernel_initializer=initializer, input_shape=(32,1))))
  model_naive_lstm.add(Dropout(0.4))
  model_naive_lstm.add(Dense(4, activation='softmax'))

  model_naive_lstm.build((None, int(max_timeStep/2), 1, 22))

  # Printing the model summary
  if debug_mode:
    model_naive_lstm.summary()

  model_naive_lstm_optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

  # Compiling the model
  model_naive_lstm.compile(loss='categorical_crossentropy',
                  optimizer=model_naive_lstm_optimizer,
                  metrics=['accuracy'])

  return model_naive_lstm

# %% [markdown]
# ##(Naive LSTM) Compiling, training and validating the model

# %%
# Model parameters
n_epochs = 100

# Creating and compiling the model
model_naive_lstm = naive_LSTM(k_initializer, debug_mode=True)

# Training and validating the model
model_naive_lstm_results = model_naive_lstm.fit(x__train,
             y__train,
             batch_size=64,
             epochs=n_epochs,
             validation_data=(x__valid, y__valid), verbose=True)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 5500)              0
#
#  dense_12 (Dense)            (None, 250)               1375250
#
#  reshape_13 (Reshape)        (None, 250, 1)            0
#
#  bidirectional_12 (Bidirecti  (None, 64)               8704
#  onal)
#
#  reshape_14 (Reshape)        (None, 64, 1)             0
#
#  bidirectional_13 (Bidirecti  (None, 32)               2304
#  onal)
#
#  reshape_15 (Reshape)        (None, 32, 1)             0
#
#  bidirectional_14 (Bidirecti  (None, 16)               640
#  onal)
#
#  dropout_16 (Dropout)        (None, 16)                0
#
#  dense_13 (Dense)            (None, 4)                 68
#
# =================================================================
# Total params: 1,386,966
# Trainable params: 1,386,966
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 110/110 [==============================] - 27s 144ms/step - loss: 1.3773 - accuracy: 0.2887 - val_loss: 1.3863 - val_accuracy: 0.2876
# Epoch 2/100
# 110/110 [==============================] - 12s 111ms/step - loss: 1.3598 - accuracy: 0.3233 - val_loss: 1.3817 - val_accuracy: 0.2730
# Epoch 3/100
# 110/110 [==============================] - 12s 112ms/step - loss: 1.3416 - accuracy: 0.3528 - val_loss: 1.3881 - val_accuracy: 0.3001
# Epoch 4/100
# 110/110 [==============================] - 12s 111ms/step - loss: 1.3273 - accuracy: 0.3660 - val_loss: 1.3912 - val_accuracy: 0.3106
# Epoch 5/100
# 110/110 [==============================] - 12s 112ms/step - loss: 1.3030 - accuracy: 0.3966 - val_loss: 1.3790 - val_accuracy: 0.3162
# Epoch 6/100
# 110/110 [==============================] - 12s 109ms/step - loss: 1.2814 - accuracy: 0.4093 - val_loss: 1.3706 - val_accuracy: 0.3398
# Epoch 7/100
# 110/110 [==============================] - 13s 116ms/step - loss: 1.2608 - accuracy: 0.4220 - val_loss: 1.3776 - val_accuracy: 0.3169
# Epoch 8/100
# 110/110 [==============================] - 12s 106ms/step - loss: 1.2510 - accuracy: 0.4337 - val_loss: 1.3544 - val_accuracy: 0.3740
# Epoch 9/100
# 110/110 [==============================] - 12s 107ms/step - loss: 1.2322 - accuracy: 0.4453 - val_loss: 1.3578 - val_accuracy: 0.3670
# Epoch 10/100
# 110/110 [==============================] - 12s 111ms/step - loss: 1.2101 - accuracy: 0.4636 - val_loss: 1.3484 - val_accuracy: 0.3670
# Epoch 11/100
# 110/110 [==============================] - 12s 110ms/step - loss: 1.1906 - accuracy: 0.4811 - val_loss: 1.3649 - val_accuracy: 0.3691
# Epoch 12/100
# 110/110 [==============================] - 12s 113ms/step - loss: 1.1575 - accuracy: 0.5007 - val_loss: 1.4027 - val_accuracy: 0.3482
# Epoch 13/100
# 110/110 [==============================] - 12s 111ms/step - loss: 1.1239 - accuracy: 0.5164 - val_loss: 1.4111 - val_accuracy: 0.3461
# Epoch 14/100
# 110/110 [==============================] - 12s 109ms/step - loss: 1.1294 - accuracy: 0.5122 - val_loss: 1.3681 - val_accuracy: 0.3935
# Epoch 15/100
# 110/110 [==============================] - 12s 110ms/step - loss: 1.1197 - accuracy: 0.5182 - val_loss: 1.3939 - val_accuracy: 0.3907
# Epoch 16/100
# 110/110 [==============================] - 12s 111ms/step - loss: 1.0918 - accuracy: 0.5282 - val_loss: 1.4092 - val_accuracy: 0.3726
# Epoch 17/100
# 110/110 [==============================] - 12s 110ms/step - loss: 1.0926 - accuracy: 0.5335 - val_loss: 1.4173 - val_accuracy: 0.3740
# Epoch 18/100
# 110/110 [==============================] - 12s 111ms/step - loss: 1.0580 - accuracy: 0.5473 - val_loss: 1.4343 - val_accuracy: 0.3914
# Epoch 19/100
# 110/110 [==============================] - 12s 112ms/step - loss: 1.0434 - accuracy: 0.5628 - val_loss: 1.4513 - val_accuracy: 0.3614
# Epoch 20/100
# 110/110 [==============================] - 12s 112ms/step - loss: 1.0190 - accuracy: 0.5715 - val_loss: 1.4732 - val_accuracy: 0.3726
# Epoch 21/100
# 110/110 [==============================] - 12s 110ms/step - loss: 1.0023 - accuracy: 0.5757 - val_loss: 1.4871 - val_accuracy: 0.3614
# Epoch 22/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.9708 - accuracy: 0.5977 - val_loss: 1.4640 - val_accuracy: 0.4046
# Epoch 23/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.9444 - accuracy: 0.6054 - val_loss: 1.5132 - val_accuracy: 0.3670
# Epoch 24/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.9406 - accuracy: 0.6075 - val_loss: 1.4413 - val_accuracy: 0.3942
# Epoch 25/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.9227 - accuracy: 0.6182 - val_loss: 1.5077 - val_accuracy: 0.3886
# Epoch 26/100
# 110/110 [==============================] - 12s 107ms/step - loss: 0.8849 - accuracy: 0.6350 - val_loss: 1.5304 - val_accuracy: 0.3900
# Epoch 27/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.8775 - accuracy: 0.6371 - val_loss: 1.5726 - val_accuracy: 0.3753
# Epoch 28/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.8585 - accuracy: 0.6449 - val_loss: 1.5991 - val_accuracy: 0.3781
# Epoch 29/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.8494 - accuracy: 0.6462 - val_loss: 1.5855 - val_accuracy: 0.4039
# Epoch 30/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.8324 - accuracy: 0.6529 - val_loss: 1.7043 - val_accuracy: 0.3663
# Epoch 31/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.8265 - accuracy: 0.6614 - val_loss: 1.6116 - val_accuracy: 0.3656
# Epoch 32/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.8028 - accuracy: 0.6733 - val_loss: 1.6073 - val_accuracy: 0.4025
# Epoch 33/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.7709 - accuracy: 0.6852 - val_loss: 1.6645 - val_accuracy: 0.3962
# Epoch 34/100
# 110/110 [==============================] - 12s 112ms/step - loss: 0.7595 - accuracy: 0.6851 - val_loss: 1.7214 - val_accuracy: 0.4143
# Epoch 35/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.7468 - accuracy: 0.6909 - val_loss: 1.6472 - val_accuracy: 0.4060
# Epoch 36/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.7338 - accuracy: 0.7024 - val_loss: 1.6313 - val_accuracy: 0.3990
# Epoch 37/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.7259 - accuracy: 0.7073 - val_loss: 1.7705 - val_accuracy: 0.3921
# Epoch 38/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.6945 - accuracy: 0.7271 - val_loss: 1.7825 - val_accuracy: 0.3997
# Epoch 39/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.7096 - accuracy: 0.7192 - val_loss: 1.7535 - val_accuracy: 0.3942
# Epoch 40/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.6650 - accuracy: 0.7386 - val_loss: 1.7873 - val_accuracy: 0.3886
# Epoch 41/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.6780 - accuracy: 0.7363 - val_loss: 1.7197 - val_accuracy: 0.3928
# Epoch 42/100
# 110/110 [==============================] - 12s 106ms/step - loss: 0.6640 - accuracy: 0.7423 - val_loss: 1.7314 - val_accuracy: 0.3983
# Epoch 43/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.6351 - accuracy: 0.7503 - val_loss: 1.8513 - val_accuracy: 0.4109
# Epoch 44/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.6094 - accuracy: 0.7667 - val_loss: 1.7729 - val_accuracy: 0.3893
# Epoch 45/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.6291 - accuracy: 0.7523 - val_loss: 1.8209 - val_accuracy: 0.4227
# Epoch 46/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.6449 - accuracy: 0.7466 - val_loss: 1.7460 - val_accuracy: 0.4004
# Epoch 47/100
# 110/110 [==============================] - 12s 108ms/step - loss: 0.6588 - accuracy: 0.7459 - val_loss: 1.7731 - val_accuracy: 0.4178
# Epoch 48/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.6196 - accuracy: 0.7681 - val_loss: 1.7818 - val_accuracy: 0.4081
# Epoch 49/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.5915 - accuracy: 0.7799 - val_loss: 1.8627 - val_accuracy: 0.4150
# Epoch 50/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.6644 - accuracy: 0.7503 - val_loss: 1.6931 - val_accuracy: 0.4123
# Epoch 51/100
# 110/110 [==============================] - 12s 108ms/step - loss: 0.6056 - accuracy: 0.7745 - val_loss: 1.7761 - val_accuracy: 0.4269
# Epoch 52/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.6048 - accuracy: 0.7694 - val_loss: 1.7344 - val_accuracy: 0.4123
# Epoch 53/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.5633 - accuracy: 0.7829 - val_loss: 1.8705 - val_accuracy: 0.4171
# Epoch 54/100
# 110/110 [==============================] - 12s 107ms/step - loss: 0.5530 - accuracy: 0.7983 - val_loss: 1.8726 - val_accuracy: 0.4164
# Epoch 55/100
# 110/110 [==============================] - 12s 107ms/step - loss: 0.5780 - accuracy: 0.7842 - val_loss: 1.7954 - val_accuracy: 0.4262
# Epoch 56/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.5386 - accuracy: 0.8021 - val_loss: 1.8730 - val_accuracy: 0.4185
# Epoch 57/100
# 110/110 [==============================] - 12s 106ms/step - loss: 0.5349 - accuracy: 0.8085 - val_loss: 1.8201 - val_accuracy: 0.4164
# Epoch 58/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.5367 - accuracy: 0.8078 - val_loss: 1.9193 - val_accuracy: 0.4039
# Epoch 59/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.5392 - accuracy: 0.8021 - val_loss: 1.9181 - val_accuracy: 0.4318
# Epoch 60/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.5263 - accuracy: 0.8092 - val_loss: 1.8778 - val_accuracy: 0.4269
# Epoch 61/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.5066 - accuracy: 0.8119 - val_loss: 1.9295 - val_accuracy: 0.4164
# Epoch 62/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.4622 - accuracy: 0.8317 - val_loss: 2.0222 - val_accuracy: 0.4325
# Epoch 63/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.4970 - accuracy: 0.8198 - val_loss: 1.9102 - val_accuracy: 0.4499
# Epoch 64/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.5135 - accuracy: 0.8118 - val_loss: 1.9857 - val_accuracy: 0.4136
# Epoch 65/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.4711 - accuracy: 0.8294 - val_loss: 2.0181 - val_accuracy: 0.4331
# Epoch 66/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.5134 - accuracy: 0.8104 - val_loss: 1.8492 - val_accuracy: 0.4276
# Epoch 67/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.4895 - accuracy: 0.8239 - val_loss: 1.9613 - val_accuracy: 0.4352
# Epoch 68/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.4686 - accuracy: 0.8309 - val_loss: 2.0440 - val_accuracy: 0.4192
# Epoch 69/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.4523 - accuracy: 0.8380 - val_loss: 2.0512 - val_accuracy: 0.4276
# Epoch 70/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.4261 - accuracy: 0.8539 - val_loss: 2.0922 - val_accuracy: 0.4582
# Epoch 71/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.4394 - accuracy: 0.8484 - val_loss: 2.1495 - val_accuracy: 0.4234
# Epoch 72/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.4369 - accuracy: 0.8430 - val_loss: 2.1111 - val_accuracy: 0.4513
# Epoch 73/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.4278 - accuracy: 0.8487 - val_loss: 2.1724 - val_accuracy: 0.4345
# Epoch 74/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.4274 - accuracy: 0.8507 - val_loss: 2.1291 - val_accuracy: 0.4255
# Epoch 75/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.4302 - accuracy: 0.8498 - val_loss: 2.1215 - val_accuracy: 0.4164
# Epoch 76/100
# 110/110 [==============================] - 12s 106ms/step - loss: 0.4204 - accuracy: 0.8536 - val_loss: 2.2417 - val_accuracy: 0.4255
# Epoch 77/100
# 110/110 [==============================] - 12s 107ms/step - loss: 0.4008 - accuracy: 0.8589 - val_loss: 2.3605 - val_accuracy: 0.4311
# Epoch 78/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.4722 - accuracy: 0.8300 - val_loss: 2.1567 - val_accuracy: 0.4276
# Epoch 79/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.4107 - accuracy: 0.8566 - val_loss: 2.1825 - val_accuracy: 0.4526
# Epoch 80/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.4167 - accuracy: 0.8573 - val_loss: 2.2562 - val_accuracy: 0.4130
# Epoch 81/100
# 110/110 [==============================] - 12s 111ms/step - loss: 0.3605 - accuracy: 0.8774 - val_loss: 2.3595 - val_accuracy: 0.4373
# Epoch 82/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.3658 - accuracy: 0.8783 - val_loss: 2.3130 - val_accuracy: 0.4234
# Epoch 83/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.3723 - accuracy: 0.8740 - val_loss: 2.3337 - val_accuracy: 0.4234
# Epoch 84/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.3906 - accuracy: 0.8645 - val_loss: 2.4080 - val_accuracy: 0.4471
# Epoch 85/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.3592 - accuracy: 0.8794 - val_loss: 2.3589 - val_accuracy: 0.4422
# Epoch 86/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.3557 - accuracy: 0.8823 - val_loss: 2.4469 - val_accuracy: 0.4422
# Epoch 87/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.4418 - accuracy: 0.8454 - val_loss: 2.3010 - val_accuracy: 0.4450
# Epoch 88/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.3969 - accuracy: 0.8628 - val_loss: 2.3208 - val_accuracy: 0.4352
# Epoch 89/100
# 110/110 [==============================] - 12s 113ms/step - loss: 0.3682 - accuracy: 0.8727 - val_loss: 2.4149 - val_accuracy: 0.4304
# Epoch 90/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.3383 - accuracy: 0.8867 - val_loss: 2.4252 - val_accuracy: 0.4345
# Epoch 91/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.3439 - accuracy: 0.8850 - val_loss: 2.3817 - val_accuracy: 0.4248
# Epoch 92/100
# 110/110 [==============================] - 12s 108ms/step - loss: 0.3200 - accuracy: 0.8914 - val_loss: 2.5046 - val_accuracy: 0.4478
# Epoch 93/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.2849 - accuracy: 0.9063 - val_loss: 2.6573 - val_accuracy: 0.4234
# Epoch 94/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.2872 - accuracy: 0.9056 - val_loss: 2.6100 - val_accuracy: 0.4290
# Epoch 95/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.3307 - accuracy: 0.8877 - val_loss: 2.5270 - val_accuracy: 0.4366
# Epoch 96/100
# 110/110 [==============================] - 12s 106ms/step - loss: 0.3222 - accuracy: 0.8938 - val_loss: 2.6029 - val_accuracy: 0.3997
# Epoch 97/100
# 110/110 [==============================] - 12s 109ms/step - loss: 0.3722 - accuracy: 0.8747 - val_loss: 2.3891 - val_accuracy: 0.4227
# Epoch 98/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.3437 - accuracy: 0.8855 - val_loss: 2.4821 - val_accuracy: 0.4297
# Epoch 99/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.3107 - accuracy: 0.8944 - val_loss: 2.5489 - val_accuracy: 0.4436
# Epoch 100/100
# 110/110 [==============================] - 12s 110ms/step - loss: 0.3384 - accuracy: 0.8857 - val_loss: 2.6920 - val_accuracy: 0.4241

# %% [markdown]
# ##(Naive LSTM) Visualizing the accuracy and loss trajectory

# %%
# Plotting accuracy trajectory
plt.plot(model_naive_lstm_results.history['accuracy'])
plt.plot(model_naive_lstm_results.history['val_accuracy'])
plt.title('Naive LSTM model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(model_naive_lstm_results.history['loss'],'o')
plt.plot(model_naive_lstm_results.history['val_loss'],'o')
plt.title('Naive LSTM model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ##(Naive LSTM) Testing the performance

# %%
## Testing the Naive LSTM model

model_naive_lstm_score = model_naive_lstm.evaluate(x__test, y__test, verbose=0)
print('Test accuracy of the Naive LSTM model:',model_naive_lstm_score[1])
# Out:
# Test accuracy of the Naive LSTM model: 0.3961625397205353
