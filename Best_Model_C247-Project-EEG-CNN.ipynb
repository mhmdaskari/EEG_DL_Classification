# %% [markdown]
# ##Importing the necessary packages

# %%
import numpy as np
import pandas as pd
import time
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import LeakyReLU, Dense, Bidirectional, Activation, Flatten, Dropout
from keras.layers import Conv2DTranspose, Conv2D, LSTM, BatchNormalization, MaxPooling2D, Reshape
from keras.utils import to_categorical
from keras.regularizers import L1L2
from keras.initializers import lecun_uniform
from keras.optimizers import Adam
from keras.metrics import categorical_accuracy
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/ECE247-Project"
X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")
# Out:
# /content/drive/.shortcut-targets-by-id/1ELPC9CkLUbTPdE0JP9VLaPzrtY2b7Uf_/ECE247-Project

# %%
# setup tensorflow + TPU 
print("Tensorflow version " + tf.__version__)

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
  print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
  raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.TPUStrategy(tpu)
# Out:
# Tensorflow version 2.11.0
# Running on TPU  ['10.101.90.138:8470']
# WARNING:tensorflow:TPU system grpc://10.101.90.138:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.

# %% [markdown]
# ##Loading and visualizing the dataset

# %%
## Loading and visualizing the data

## Adjusting the labels so that 

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

## Visualizing the data

ch_data = X_train_valid[:,8,:] # extracts the 9th channel from the data


class_0_ind = np.where(y_train_valid == 0) # finds the indices where the label is 0
ch_data_class_0 = ch_data[class_0_ind] # finds the data where label is 0
avg_ch_data_class_0 = np.mean(ch_data_class_0,axis=0) # finds the average representation of the 9th channel when label is 0


class_1_ind = np.where(y_train_valid == 1)
ch_data_class_1 = ch_data[class_1_ind]
avg_ch_data_class_1 = np.mean(ch_data_class_1,axis=0)

class_2_ind = np.where(y_train_valid == 2)
ch_data_class_2 = ch_data[class_2_ind]
avg_ch_data_class_2 = np.mean(ch_data_class_2,axis=0)

class_3_ind = np.where(y_train_valid == 3)
ch_data_class_3 = ch_data[class_3_ind]
avg_ch_data_class_3 = np.mean(ch_data_class_3,axis=0)


plt.plot(np.arange(1000),avg_ch_data_class_0)
plt.plot(np.arange(1000),avg_ch_data_class_1)
plt.plot(np.arange(1000),avg_ch_data_class_2)
plt.plot(np.arange(1000),avg_ch_data_class_3)
plt.axvline(x=500, label='line at t=500',c='cyan')

plt.legend(["Cue Onset left", "Cue Onset right", "Cue onset foot", "Cue onset tongue"])

# %%
#Numpy and Keras Random Seed Assignment
np.random.seed(1)
k_initializer = lecun_uniform(seed=42)

# %%
def data_prep(X, y, sub_sample, average, noise, max_timeStep=500, debug_mode=False):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,max_timeStep)
    X = X[:,:,0:max_timeStep]
    if debug_mode: print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    if debug_mode: print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    if debug_mode: print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    if debug_mode: print('Shape of X after subsampling and concatenating:',total_X.shape)
    return total_X,total_y


# X_train_valid_prep,y_train_valid_prep = data_prep(X_train_valid, y_train_valid, 2, 2, True, 1000, True)

# %% [markdown]
# ##Preparing the training, validation, and test datasets

# %%
## Random splitting and reshaping the data
def data_train_valid_test_split(sub_sample=2, average=2, noise=True, sobject_id=None, max_timeStep=500, debug_mode=False):

  # Check if we are generating the model for the whole subject
  if sobject_id:
    X_train_sub = X_train_valid[np.where(person_train_valid == sobject_id)[0]]
    y_train_sub = y_train_valid[np.where(person_train_valid == sobject_id)[0]]
    X_test_sub = X_test[np.where(person_test == sobject_id)[0]]
    y_test_sub = y_test[np.where(person_test == sobject_id)[0]]
  else:
    X_train_sub = np.copy(X_train_valid)
    y_train_sub = np.copy(y_train_valid)
    X_test_sub = np.copy(X_test)
    y_test_sub = np.copy(y_test)

  # First generating the training and validation indices using random splitting
  # Since the ratio of test set to the whole training set is about 17%, we chose
  # the same ratio for spliting the training and validation set
  n_train_valid = X_train_sub.shape[0]
  n_valid = int(np.floor(0.17*n_train_valid))
  ind_valid = np.random.choice(n_train_valid, n_valid, replace=False)
  ind_train = np.array(list(set(range(n_train_valid)).difference(set(ind_valid))))

  # Creating the training and validation sets using the generated indices
  (X_train, X_valid) = X_train_sub[ind_train], X_train_sub[ind_valid] 
  (y_train, y_valid) = y_train_sub[ind_train], y_train_sub[ind_valid]


  ## Preprocessing the dataset
  x_train,y_train = data_prep(X_train, y_train, sub_sample, average, noise, max_timeStep, debug_mode)
  x_valid,y_valid = data_prep(X_valid, y_valid, sub_sample, average, noise, max_timeStep, debug_mode)
  X_test_prep,y_test_prep = data_prep(X_test_sub, y_test_sub, sub_sample, average, noise, max_timeStep, debug_mode)

  if debug_mode:
    print('Shape of testing set:',X_test_prep.shape)
    print('Shape of testing labels:',y_test_prep.shape)

    print('Shape of training set:',x_train.shape)
    print('Shape of validation set:',x_valid.shape)
    print('Shape of training labels:',y_train.shape)
    print('Shape of validation labels:',y_valid.shape)


  # Converting the labels to categorical variables for multiclass classification
  y__train = to_categorical(y_train, 4)
  y__valid = to_categorical(y_valid, 4)
  y__test = to_categorical(y_test_prep, 4)

  if debug_mode:
    print('Shape of training labels after categorical conversion:',y_train.shape)
    print('Shape of validation labels after categorical conversion:',y_valid.shape)
    print('Shape of test labels after categorical conversion:',y_test.shape)

  # Adding width of the segment to be 1
  x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
  x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
  x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
  if debug_mode:
    print('Shape of training set after adding width info:',x_train.shape)
    print('Shape of validation set after adding width info:',x_valid.shape)
    print('Shape of test set after adding width info:',x_test.shape)


  # Reshaping the training and validation dataset
  x__train = np.swapaxes(x_train, 1,3)
  x__train = np.swapaxes(x__train, 1,2)
  x__valid = np.swapaxes(x_valid, 1,3)
  x__valid = np.swapaxes(x__valid, 1,2)
  x__test = np.swapaxes(x_test, 1,3)
  x__test = np.swapaxes(x__test, 1,2)
  
  if debug_mode:
    print('Shape of training set after dimension reshaping:',x__train.shape)
    print('Shape of validation set after dimension reshaping:',x__valid.shape)
    print('Shape of test set after dimension reshaping:',x__test.shape)

  return x__train, y__train, x__valid, y__valid, x__test, y__test

# %%
# Generating Train, Validation, and Test data set
x__train, y__train, x__valid, y__valid, x__test, y__test = data_train_valid_test_split(sub_sample=2, average=2, noise=True, sobject_id=None, max_timeStep=1000, debug_mode=True)
# Out:
# Shape of X after trimming: (1756, 22, 1000)
# Shape of X after maxpooling: (1756, 22, 500)
# Shape of X after averaging+noise and concatenating: (3512, 22, 500)
# Shape of X after subsampling and concatenating: (7024, 22, 500)
# Shape of X after trimming: (359, 22, 1000)
# Shape of X after maxpooling: (359, 22, 500)
# Shape of X after averaging+noise and concatenating: (718, 22, 500)
# Shape of X after subsampling and concatenating: (1436, 22, 500)
# Shape of X after trimming: (443, 22, 1000)
# Shape of X after maxpooling: (443, 22, 500)
# Shape of X after averaging+noise and concatenating: (886, 22, 500)
# Shape of X after subsampling and concatenating: (1772, 22, 500)
# Shape of testing set: (1772, 22, 500)
# Shape of testing labels: (1772,)
# Shape of training set: (7024, 22, 500)
# Shape of validation set: (1436, 22, 500)
# Shape of training labels: (7024,)
# Shape of validation labels: (1436,)
# Shape of training labels after categorical conversion: (7024,)
# Shape of validation labels after categorical conversion: (1436,)
# Shape of test labels after categorical conversion: (443,)
# Shape of training set after adding width info: (7024, 22, 500, 1)
# Shape of validation set after adding width info: (1436, 22, 500, 1)
# Shape of test set after adding width info: (1772, 22, 500, 1)
# Shape of training set after dimension reshaping: (7024, 500, 1, 22)
# Shape of validation set after dimension reshaping: (1436, 500, 1, 22)
# Shape of test set after dimension reshaping: (1772, 500, 1, 22)

# %% [markdown]
# #(CNN)

# %% [markdown]
# ##(CNN) Defining the architecture of a basic CNN model

# %%
def CNN(initializer, max_timeStep=500, debug_mode=False, learning_rate=1e-3):
  # Building the CNN model using sequential class
  basic_cnn_model = Sequential()

  # Conv. block 1
  basic_cnn_model.add(Conv2D(filters=25, kernel_size=(10,1), padding='same', activation='elu', input_shape=(int(max_timeStep/2),1,22)))
  basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same')) 
  basic_cnn_model.add(BatchNormalization())
  basic_cnn_model.add(Dropout(0.5))

  # Conv. block 2
  basic_cnn_model.add(Conv2D(filters=50, kernel_size=(10,1), padding='same', activation='elu'))
  basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
  basic_cnn_model.add(BatchNormalization())
  basic_cnn_model.add(Dropout(0.5))

  # Conv. block 3
  basic_cnn_model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu'))
  basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
  basic_cnn_model.add(BatchNormalization())
  basic_cnn_model.add(Dropout(0.5))

  # Conv. block 4
  basic_cnn_model.add(Conv2D(filters=200, kernel_size=(10,1), padding='same', activation='elu'))
  basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
  basic_cnn_model.add(BatchNormalization())
  basic_cnn_model.add(Dropout(0.5))

  # Output layer with Softmax activation
  basic_cnn_model.add(Flatten()) # Flattens the input
  basic_cnn_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation

  # Printing the model summary
  if debug_mode:
    basic_cnn_model.summary()

  cnn_optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

  # Compiling the model
  basic_cnn_model.compile(loss='categorical_crossentropy',
                  optimizer=cnn_optimizer,
                  metrics=['accuracy'])

  return basic_cnn_model

# %% [markdown]
# ##(CNN) Compiling, training and validating the model

# %%
n_epochs=100

# Creating and compiling the model
basic_cnn_model = CNN(k_initializer, max_timeStep=1000, debug_mode=True)

# Training and validating the model
basic_cnn_model_results = basic_cnn_model.fit(x__train,
            y__train,
            batch_size=64,
            epochs=n_epochs,
            validation_data=(x__valid, y__valid), verbose=True)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_60 (Conv2D)          (None, 500, 1, 25)        5525
#
#  max_pooling2d_60 (MaxPoolin  (None, 167, 1, 25)       0
#  g2D)
#
#  batch_normalization_60 (Bat  (None, 167, 1, 25)       100
#  chNormalization)
#
#  dropout_60 (Dropout)        (None, 167, 1, 25)        0
#
#  conv2d_61 (Conv2D)          (None, 167, 1, 50)        12550
#
#  max_pooling2d_61 (MaxPoolin  (None, 56, 1, 50)        0
#  g2D)
#
#  batch_normalization_61 (Bat  (None, 56, 1, 50)        200
#  chNormalization)
#
#  dropout_61 (Dropout)        (None, 56, 1, 50)         0
#
#  conv2d_62 (Conv2D)          (None, 56, 1, 100)        50100
#
#  max_pooling2d_62 (MaxPoolin  (None, 19, 1, 100)       0
#  g2D)
#
#  batch_normalization_62 (Bat  (None, 19, 1, 100)       400
#  chNormalization)
#
#  dropout_62 (Dropout)        (None, 19, 1, 100)        0
#
#  conv2d_63 (Conv2D)          (None, 19, 1, 200)        200200
#
#  max_pooling2d_63 (MaxPoolin  (None, 7, 1, 200)        0
#  g2D)
#
#  batch_normalization_63 (Bat  (None, 7, 1, 200)        800
#  chNormalization)
#
#  dropout_63 (Dropout)        (None, 7, 1, 200)         0
#
#  flatten_15 (Flatten)        (None, 1400)              0
#
#  dense_15 (Dense)            (None, 4)                 5604
#
# =================================================================
# Total params: 275,479
# Trainable params: 274,729
# Non-trainable params: 750
# _________________________________________________________________
# Epoch 1/100
# 110/110 [==============================] - 6s 41ms/step - loss: 1.9540 - accuracy: 0.3195 - val_loss: 2.0308 - val_accuracy: 0.3071
# Epoch 2/100
# 110/110 [==============================] - 4s 32ms/step - loss: 1.5820 - accuracy: 0.3687 - val_loss: 1.3202 - val_accuracy: 0.4102
# Epoch 3/100
# 110/110 [==============================] - 4s 32ms/step - loss: 1.3711 - accuracy: 0.4274 - val_loss: 1.2582 - val_accuracy: 0.3976
# Epoch 4/100
# 110/110 [==============================] - 4s 32ms/step - loss: 1.2343 - accuracy: 0.4835 - val_loss: 1.1859 - val_accuracy: 0.4735
# Epoch 5/100
# 110/110 [==============================] - 3s 31ms/step - loss: 1.1338 - accuracy: 0.5285 - val_loss: 1.2196 - val_accuracy: 0.4708
# Epoch 6/100
# 110/110 [==============================] - 3s 31ms/step - loss: 1.0527 - accuracy: 0.5609 - val_loss: 1.1893 - val_accuracy: 0.4979
# Epoch 7/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.9844 - accuracy: 0.6012 - val_loss: 1.1651 - val_accuracy: 0.4972
# Epoch 8/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.9184 - accuracy: 0.6266 - val_loss: 1.1366 - val_accuracy: 0.5425
# Epoch 9/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.8733 - accuracy: 0.6577 - val_loss: 1.0257 - val_accuracy: 0.5891
# Epoch 10/100
# 110/110 [==============================] - 4s 33ms/step - loss: 0.8170 - accuracy: 0.6701 - val_loss: 1.0634 - val_accuracy: 0.5474
# Epoch 11/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.7987 - accuracy: 0.6800 - val_loss: 1.0146 - val_accuracy: 0.5884
# Epoch 12/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.7640 - accuracy: 0.6989 - val_loss: 1.1078 - val_accuracy: 0.5933
# Epoch 13/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.7130 - accuracy: 0.7234 - val_loss: 1.1056 - val_accuracy: 0.5794
# Epoch 14/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.6968 - accuracy: 0.7201 - val_loss: 1.0093 - val_accuracy: 0.6128
# Epoch 15/100
# 110/110 [==============================] - 4s 33ms/step - loss: 0.6536 - accuracy: 0.7436 - val_loss: 0.9782 - val_accuracy: 0.6330
# Epoch 16/100
# 110/110 [==============================] - 4s 33ms/step - loss: 0.6201 - accuracy: 0.7610 - val_loss: 0.9865 - val_accuracy: 0.6219
# Epoch 17/100
# 110/110 [==============================] - 3s 30ms/step - loss: 0.5842 - accuracy: 0.7776 - val_loss: 1.0353 - val_accuracy: 0.6274
# Epoch 18/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.5669 - accuracy: 0.7751 - val_loss: 1.0323 - val_accuracy: 0.6476
# Epoch 19/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.5588 - accuracy: 0.7823 - val_loss: 1.1087 - val_accuracy: 0.6344
# Epoch 20/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.5340 - accuracy: 0.7909 - val_loss: 0.9975 - val_accuracy: 0.6504
# Epoch 21/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.5083 - accuracy: 0.8099 - val_loss: 1.0003 - val_accuracy: 0.6330
# Epoch 22/100
# 110/110 [==============================] - 4s 33ms/step - loss: 0.4835 - accuracy: 0.8112 - val_loss: 0.9399 - val_accuracy: 0.6811
# Epoch 23/100
# 110/110 [==============================] - 4s 33ms/step - loss: 0.4620 - accuracy: 0.8153 - val_loss: 1.0431 - val_accuracy: 0.6442
# Epoch 24/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.4389 - accuracy: 0.8329 - val_loss: 1.0372 - val_accuracy: 0.6330
# Epoch 25/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.4448 - accuracy: 0.8307 - val_loss: 1.0610 - val_accuracy: 0.6400
# Epoch 26/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.4363 - accuracy: 0.8343 - val_loss: 1.0164 - val_accuracy: 0.6442
# Epoch 27/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.4110 - accuracy: 0.8410 - val_loss: 1.0404 - val_accuracy: 0.6518
# Epoch 28/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.4155 - accuracy: 0.8420 - val_loss: 1.0151 - val_accuracy: 0.6643
# Epoch 29/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.3945 - accuracy: 0.8442 - val_loss: 1.0682 - val_accuracy: 0.6462
# Epoch 30/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.3665 - accuracy: 0.8615 - val_loss: 1.1154 - val_accuracy: 0.6288
# Epoch 31/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.3656 - accuracy: 0.8583 - val_loss: 1.1233 - val_accuracy: 0.6483
# Epoch 32/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.3547 - accuracy: 0.8646 - val_loss: 1.1168 - val_accuracy: 0.6560
# Epoch 33/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.3584 - accuracy: 0.8696 - val_loss: 1.0583 - val_accuracy: 0.6623
# Epoch 34/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.3247 - accuracy: 0.8784 - val_loss: 1.1177 - val_accuracy: 0.6462
# Epoch 35/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.3146 - accuracy: 0.8838 - val_loss: 1.0100 - val_accuracy: 0.6783
# Epoch 36/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.3222 - accuracy: 0.8814 - val_loss: 1.1288 - val_accuracy: 0.6762
# Epoch 37/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.3158 - accuracy: 0.8798 - val_loss: 1.1018 - val_accuracy: 0.6797
# Epoch 38/100
# 110/110 [==============================] - 4s 33ms/step - loss: 0.3068 - accuracy: 0.8810 - val_loss: 1.1325 - val_accuracy: 0.6428
# Epoch 39/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.2885 - accuracy: 0.8895 - val_loss: 1.1101 - val_accuracy: 0.6609
# Epoch 40/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.2974 - accuracy: 0.8884 - val_loss: 1.1761 - val_accuracy: 0.6316
# Epoch 41/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.2955 - accuracy: 0.8951 - val_loss: 1.1162 - val_accuracy: 0.6609
# Epoch 42/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.2905 - accuracy: 0.8911 - val_loss: 1.1635 - val_accuracy: 0.6462
# Epoch 43/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.2897 - accuracy: 0.8908 - val_loss: 1.1019 - val_accuracy: 0.6678
# Epoch 44/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.2720 - accuracy: 0.9008 - val_loss: 1.1713 - val_accuracy: 0.6671
# Epoch 45/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.2745 - accuracy: 0.8978 - val_loss: 1.0774 - val_accuracy: 0.6769
# Epoch 46/100
# 110/110 [==============================] - 3s 30ms/step - loss: 0.2659 - accuracy: 0.8995 - val_loss: 1.1750 - val_accuracy: 0.6553
# Epoch 47/100
# 110/110 [==============================] - 3s 30ms/step - loss: 0.2711 - accuracy: 0.9016 - val_loss: 1.1832 - val_accuracy: 0.6483
# Epoch 48/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.2428 - accuracy: 0.9110 - val_loss: 1.1151 - val_accuracy: 0.6664
# Epoch 49/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.2424 - accuracy: 0.9123 - val_loss: 1.0884 - val_accuracy: 0.6643
# Epoch 50/100
# 110/110 [==============================] - 3s 30ms/step - loss: 0.2409 - accuracy: 0.9139 - val_loss: 1.1541 - val_accuracy: 0.6727
# Epoch 51/100
# 110/110 [==============================] - 3s 30ms/step - loss: 0.2320 - accuracy: 0.9129 - val_loss: 1.1910 - val_accuracy: 0.6421
# Epoch 52/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.2379 - accuracy: 0.9134 - val_loss: 1.1905 - val_accuracy: 0.6630
# Epoch 53/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.2408 - accuracy: 0.9106 - val_loss: 1.1148 - val_accuracy: 0.6769
# Epoch 54/100
# 110/110 [==============================] - 4s 33ms/step - loss: 0.2531 - accuracy: 0.9073 - val_loss: 1.1682 - val_accuracy: 0.6609
# Epoch 55/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.2194 - accuracy: 0.9208 - val_loss: 1.1896 - val_accuracy: 0.6825
# Epoch 56/100
# 110/110 [==============================] - 4s 39ms/step - loss: 0.2396 - accuracy: 0.9130 - val_loss: 1.1828 - val_accuracy: 0.6664
# Epoch 57/100
# 110/110 [==============================] - 4s 34ms/step - loss: 0.2214 - accuracy: 0.9193 - val_loss: 1.1565 - val_accuracy: 0.6852
# Epoch 58/100
# 110/110 [==============================] - 4s 33ms/step - loss: 0.2080 - accuracy: 0.9197 - val_loss: 1.1522 - val_accuracy: 0.6727
# Epoch 59/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1933 - accuracy: 0.9248 - val_loss: 1.0962 - val_accuracy: 0.6908
# Epoch 60/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.2125 - accuracy: 0.9208 - val_loss: 1.2067 - val_accuracy: 0.6657
# Epoch 61/100
# 110/110 [==============================] - 3s 30ms/step - loss: 0.2187 - accuracy: 0.9188 - val_loss: 1.1143 - val_accuracy: 0.6908
# Epoch 62/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.2017 - accuracy: 0.9304 - val_loss: 1.1201 - val_accuracy: 0.6859
# Epoch 63/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.2122 - accuracy: 0.9245 - val_loss: 1.2488 - val_accuracy: 0.6636
# Epoch 64/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.2013 - accuracy: 0.9277 - val_loss: 1.2121 - val_accuracy: 0.6713
# Epoch 65/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.2123 - accuracy: 0.9227 - val_loss: 1.1460 - val_accuracy: 0.6811
# Epoch 66/100
# 110/110 [==============================] - 3s 30ms/step - loss: 0.1896 - accuracy: 0.9304 - val_loss: 1.2024 - val_accuracy: 0.6678
# Epoch 67/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.1889 - accuracy: 0.9284 - val_loss: 1.2088 - val_accuracy: 0.6859
# Epoch 68/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.2131 - accuracy: 0.9206 - val_loss: 1.1674 - val_accuracy: 0.6762
# Epoch 69/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1942 - accuracy: 0.9307 - val_loss: 1.1974 - val_accuracy: 0.6866
# Epoch 70/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1886 - accuracy: 0.9288 - val_loss: 1.2188 - val_accuracy: 0.6769
# Epoch 71/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1798 - accuracy: 0.9312 - val_loss: 1.1789 - val_accuracy: 0.6630
# Epoch 72/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1706 - accuracy: 0.9381 - val_loss: 1.2028 - val_accuracy: 0.6804
# Epoch 73/100
# 110/110 [==============================] - 3s 30ms/step - loss: 0.1813 - accuracy: 0.9342 - val_loss: 1.1792 - val_accuracy: 0.6762
# Epoch 74/100
# 110/110 [==============================] - 3s 30ms/step - loss: 0.1854 - accuracy: 0.9328 - val_loss: 1.3013 - val_accuracy: 0.6476
# Epoch 75/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1807 - accuracy: 0.9327 - val_loss: 1.2446 - val_accuracy: 0.6685
# Epoch 76/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1708 - accuracy: 0.9355 - val_loss: 1.2851 - val_accuracy: 0.6720
# Epoch 77/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1873 - accuracy: 0.9304 - val_loss: 1.3099 - val_accuracy: 0.6720
# Epoch 78/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1771 - accuracy: 0.9345 - val_loss: 1.2173 - val_accuracy: 0.6838
# Epoch 79/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1856 - accuracy: 0.9338 - val_loss: 1.2101 - val_accuracy: 0.6852
# Epoch 80/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1703 - accuracy: 0.9364 - val_loss: 1.2696 - val_accuracy: 0.6790
# Epoch 81/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1906 - accuracy: 0.9284 - val_loss: 1.3084 - val_accuracy: 0.6581
# Epoch 82/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1646 - accuracy: 0.9361 - val_loss: 1.2045 - val_accuracy: 0.6790
# Epoch 83/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1685 - accuracy: 0.9362 - val_loss: 1.3619 - val_accuracy: 0.6553
# Epoch 84/100
# 110/110 [==============================] - 3s 32ms/step - loss: 0.1627 - accuracy: 0.9446 - val_loss: 1.3148 - val_accuracy: 0.6657
# Epoch 85/100
# 110/110 [==============================] - 3s 30ms/step - loss: 0.1611 - accuracy: 0.9391 - val_loss: 1.2921 - val_accuracy: 0.6699
# Epoch 86/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1584 - accuracy: 0.9405 - val_loss: 1.2801 - val_accuracy: 0.6692
# Epoch 87/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1685 - accuracy: 0.9412 - val_loss: 1.2036 - val_accuracy: 0.6831
# Epoch 88/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1525 - accuracy: 0.9416 - val_loss: 1.2965 - val_accuracy: 0.6734
# Epoch 89/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1588 - accuracy: 0.9429 - val_loss: 1.3189 - val_accuracy: 0.6581
# Epoch 90/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1649 - accuracy: 0.9415 - val_loss: 1.2956 - val_accuracy: 0.6894
# Epoch 91/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1637 - accuracy: 0.9422 - val_loss: 1.3011 - val_accuracy: 0.6713
# Epoch 92/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1630 - accuracy: 0.9425 - val_loss: 1.2650 - val_accuracy: 0.6748
# Epoch 93/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1561 - accuracy: 0.9453 - val_loss: 1.3645 - val_accuracy: 0.6636
# Epoch 94/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1603 - accuracy: 0.9421 - val_loss: 1.2842 - val_accuracy: 0.6831
# Epoch 95/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1548 - accuracy: 0.9445 - val_loss: 1.3737 - val_accuracy: 0.6546
# Epoch 96/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1568 - accuracy: 0.9412 - val_loss: 1.2979 - val_accuracy: 0.6664
# Epoch 97/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1500 - accuracy: 0.9440 - val_loss: 1.2228 - val_accuracy: 0.6915
# Epoch 98/100
# 110/110 [==============================] - 3s 31ms/step - loss: 0.1510 - accuracy: 0.9460 - val_loss: 1.2013 - val_accuracy: 0.7013
# Epoch 99/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1595 - accuracy: 0.9446 - val_loss: 1.3047 - val_accuracy: 0.6741
# Epoch 100/100
# 110/110 [==============================] - 4s 32ms/step - loss: 0.1488 - accuracy: 0.9448 - val_loss: 1.2629 - val_accuracy: 0.6797

# %% [markdown]
# ##(CNN) Visualizing the accuracy and loss trajectory

# %%
# Plotting accuracy trajectory
plt.plot(basic_cnn_model_results.history['accuracy'])
plt.plot(basic_cnn_model_results.history['val_accuracy'])
plt.title('Basic CNN model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(basic_cnn_model_results.history['loss'],'o')
plt.plot(basic_cnn_model_results.history['val_loss'],'o')
plt.title('Basic CNN model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ##(CNN) Testing the performance of the basic CNN model on the held out test set

# %%
## Testing the basic CNN model

cnn_score = basic_cnn_model.evaluate(x__test, y__test, verbose=0)
print('Test accuracy of the basic CNN model:',cnn_score[1])
# Out:
# Test accuracy of the basic CNN model: 0.6873589158058167
